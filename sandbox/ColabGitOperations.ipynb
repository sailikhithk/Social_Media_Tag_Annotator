# %% [markdown]
# ###Mount Google Drive in current runtime

# %%
from google.colab import drive
from os.path import join

# Mounting location on runtime for GDrive
ROOT = '/content/drive'

# Project workspace on GDrive
PROJECT_PATH = 'My Drive/Github'

# Mount GDrive on the runtime
drive.mount(ROOT)

# Create the full runtime project path and create a workspace at that location
WORKING_PATH = join(ROOT, PROJECT_PATH)
# !mkdir "{WORKING_PATH}"   

# Set Git repository name and its owner
GIT_USERNAME = "mentorchains"
GIT_REPOSITORY = "mlteam4"

# Set personal Git email and username
# !git config --global user.email "<To Be Filled>"
# !git config --global user.name "<To Be Filled>"

# Set Git token for personal account access
GIT_TOKEN = "<To Be Filled>"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# mkdir: cannot create directory ‘/content/drive/My Drive/Github’: File exists

# %% [markdown]
# ###Clone Github repository to the workspace in Google Drive

# %%
# Clone repository into the current folder of the runtime (/content)
REMOTE_ORIGIN = 'https://' + GIT_TOKEN + '@github.com/' + GIT_USERNAME + '/' + GIT_REPOSITORY + '.git'
# !git clone {REMOTE_ORIGIN}

# Move cloned repository to the workspace on the runtime
# !mv {GIT_REPOSITORY} "{WORKING_PATH}"
# Out:
# Cloning into 'mlteam4'...
# remote: Enumerating objects: 246, done.
# remote: Counting objects: 100% (246/246), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 246 (delta 68), reused 246 (delta 68), pack-reused 0
# Receiving objects: 100% (246/246), 15.91 MiB | 16.09 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %% [markdown]
# ### Change directory to the Git repository

# %%
REPO_PATH = join(WORKING_PATH, GIT_REPOSITORY)
# %cd "{REPO_PATH}"
# Out:
# /content/drive/My Drive/Github/mlteam4

# %% [markdown]
# ### Check Git status

# %%
# !git status
# Out:
# On branch flowster-webscraping
# Your branch is up to date with 'origin/flowster-webscraping'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	sandbox/ColabTest.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %% [markdown]
# ###Stage, commit and push changes

# %%
#!git remote add origin "{REMOTE_ORIGIN}"
COMMIT_MESSAGE = "Testing commit using Colab"
BRANCH_NAME = "flowster-webscraping"

# !git add .
# !git commit -m "{COMMIT_MESSAGE}"
# !git push origin "{BRANCH_NAME}"
# Out:
# [flowster-webscraping ed6ca97] Testing commit using Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 sandbox/ColabTest.ipynb
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 615 bytes | 153.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/stemaway-ml-juneteam4/team4mlproject.git
#    8abd411..ed6ca97  flowster-webscraping -> flowster-webscraping

# %% [markdown]
# ###Miscellaneous commands

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git checkout flowster-webscraping
# Out:
# Branch 'flowster-webscraping' set up to track remote branch 'flowster-webscraping' from 'origin'.
# Switched to a new branch 'flowster-webscraping'

# %% [markdown]
# Resources from which this file was created:
#
# https://towardsdatascience.com/google-drive-google-colab-github-dont-just-read-do-it-5554d5824228
#
# https://zerowithdot.com/colab-github-workflow/
